# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Under first order condition (i.e. let first derivative or dy/dx be 0 to find the minima or maxima),
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# - find b: conditional distribution of estimators given sample data X
# ![image.png](attachment:image.png)

# %% [markdown]
# - find a: conditional distribution of estimators given sample data X
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
