# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Bond price, Taylor Series
# ![image.png](attachment:image.png)

# %% [markdown]
# # Duration
# - duration = db/dy
# - duration of a bond = average years to receive payment
#     - zero coupon bond with maturity x years has duration of x years
#     - interest bearing bonds with maturity x years has duration <x years

# %% [markdown]
# # Convexity
# - sensitivity of duration to yield change

# %% [markdown]
# # Modified duration (most used bond duration measure)
# - modified duration = sensitivity of bond price wrt yield
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png
# - for small change in yyield of bond:
# ![image-4.png](attachment:image-4.png)
# - for lage change in yield of bond:
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# # Macaulay duration
# - macaulay duration = estimate the time in which bond price remain unchanged for small parallel change in zero rate curve
# - For continuous compounded bond yield
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)
# - for discrete compounded (which is the case for reality)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  # Dollar duration
#  - use dollar duration to analyse bond portfolios as they are non-additive (i.e. modified duration or convexity of portfolio duration != sum of that for individual bonds)
# ![image.png](attachment:image.png)
# ![image-7.png](attachment:image-7.png)
#
# # DV01 (is preferred over dollar duration)
# - dollar value of one basis point
# - measures bond price change due to decrease in 1 basis point, hence DV01 is always positive
# ![image-5.png](attachment:image-5.png)
# ![image-4.png](attachment:image-4.png)
# ![image-6.png](attachment:image-6.png)
#
# # Dollar convexity
# ![image-2.png](attachment:image-2.png)
# ![image-8.png](attachment:image-8.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)
