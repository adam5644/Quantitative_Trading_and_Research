# %% [markdown]
# ![image.png](attachment:15c0281f-a5e7-42ec-8a88-cd0942dcf647.png)
# ![image.png](attachment:622012fe-24d4-4132-891b-211c554f47b4.png)
# ![image.png](attachment:d340fa6a-d20f-477b-871c-6b726cb5259e.png)
# ![image.png](attachment:af00afcd-adf0-4ec8-971b-2097adc4cbd0.png)
# ![image.png](attachment:559c691e-337a-4460-8dd6-8eaa1106af08.png)
