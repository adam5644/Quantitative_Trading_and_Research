# %% [markdown]
# # VaR model
# - max dollar amt loss over given time horizon, at a certain confidence level
# - basil 2 accord --> banks internal VaR model at 1% significance level
# - basil 2 accord --> 10 days time horizon
# ![image.png](attachment:image.png)

# %% [markdown]
# # Qn
# ![image.png](attachment:image.png)
# # Ans
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
