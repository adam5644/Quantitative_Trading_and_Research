# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Duration / Macaulay duration / simple duration: whether pv increase or decrease if interest rate change
# ![image.png](attachment:image.png)

# %% [markdown]
# # Modified duration:
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Asset and liability changes using duration mdeol
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Immunizing equity change from interest rate risk
# ![image.png](attachment:image.png)

# %% [markdown]
# # Qn
# ![image.png](attachment:image.png)

# %% [markdown]
# # Qn
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
